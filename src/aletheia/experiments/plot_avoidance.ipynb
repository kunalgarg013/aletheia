 7.5 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in c:\users\kunal\appdata\roaming\python\python310\site-packages (from jupyter) (7.0.1)
# Collecting nbconvert
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      ---------------------------------------- 0.0/258.5 kB ? eta -:--:--
#      -------------------------------------  256.0/258.5 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------- 258.5/258.5 kB 5.3 MB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#      ---------------------------------------- 0.0/139.8 kB ? eta -:--:--
#      -------------------------------------- 139.8/139.8 kB 4.0 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ---------------------------------------- 0.0/113.9 kB ? eta -:--:--
#      -------------------------------------- 113.9/113.9 kB 6.5 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
#      ---------------------------------------- 0.0/73.7 kB ? eta -:--:--
#      ---------------------------------------- 73.7/73.7 kB 4.2 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp310-cp310-win_amd64.whl (2.3 MB)
#      ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#      ----- ---------------------------------- 0.3/2.3 MB 9.9 MB/s eta 0:00:01
#      ------------ --------------------------- 0.7/2.3 MB 8.9 MB/s eta 0:00:01
#      ------------------- -------------------- 1.1/2.3 MB 8.7 MB/s eta 0:00:01
#      -------------------- ------------------- 1.2/2.3 MB 8.3 MB/s eta 0:00:01
#      -------------------- ------------------- 1.2/2.3 MB 8.3 MB/s eta 0:00:01
#      ------------------------- -------------- 1.4/2.3 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------------- 2.3/2.3 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Using cached pillow-11.3.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Requirement already satisfied: six>=1.5 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (8.37.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter) (7.1.0)
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#      ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#      ----- ---------------------------------- 0.3/2.2 MB 6.9 MB/s eta 0:00:01
#      ------------ --------------------------- 0.7/2.2 MB 7.5 MB/s eta 0:00:01
#      ------------------- -------------------- 1.1/2.2 MB 7.8 MB/s eta 0:00:01
#      --------------------------- ------------ 1.5/2.2 MB 7.9 MB/s eta 0:00:01
#      --------------------------------- ------ 1.8/2.2 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 7.8 MB/s eta 0:00:00
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#      ---------------------------------------- 0.0/216.6 kB ? eta -:--:--
#      -------------------------------------- 216.6/216.6 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: pygments in c:\users\kunal\appdata\roaming\python\python310\site-packages (from jupyter-console->jupyter) (2.19.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from jupyter-console->jupyter) (3.0.52)
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Collecting tomli>=1.2.2
#   Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#      ---------------------------------------- 0.0/76.7 kB ? eta -:--:--
#      ---------------------------------------- 76.7/76.7 kB 4.4 MB/s eta 0:00:00
# Collecting jinja2>=3.0.3
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\kunal\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter) (65.5.0)
# Collecting httpx<1,>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting jupyterlab-server<3,>=2.27.1
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 59.7/59.7 kB 3.1 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.17.0-py3-none-any.whl (388 kB)
#      ---------------------------------------- 0.0/388.2 kB ? eta -:--:--
#      ------------------------------------  378.9/388.2 kB 11.9 MB/s eta 0:00:01
#      -------------------------------------- 388.2/388.2 kB 8.2 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting nbformat>=5.7
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Collecting markupsafe>=2.0
#   Downloading markupsafe-3.0.3-cp310-cp310-win_amd64.whl (15 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
#      ---------------------------------------- 0.0/106.4 kB ? eta -:--:--
#      -------------------------------------- 106.4/106.4 kB 6.0 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.4-py3-none-any.whl (53 kB)
#      ---------------------------------------- 0.0/53.5 kB ? eta -:--:--
#      ---------------------------------------- 53.5/53.5 kB ? eta 0:00:00
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ---------------------------------------- 0.0/163.4 kB ? eta -:--:--
#      -------------------------------------- 163.4/163.4 kB 4.9 MB/s eta 0:00:00
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from async-lru>=1.0.0->jupyterlab->jupyter) (4.15.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting certifi
#   Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
#      ---------------------------------------- 0.0/163.3 kB ? eta -:--:--
#      ------------------------------------- 163.3/163.3 kB 10.2 MB/s eta 0:00:00
# Collecting anyio
#   Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
#      ---------------------------------------- 0.0/109.1 kB ? eta -:--:--
#      -------------------------------------- 109.1/109.1 kB 6.2 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting idna
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
#      ---------------------------------------- 71.0/71.0 kB 4.1 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: jedi>=0.16 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: exceptiongroup in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.3.0)
# Requirement already satisfied: decorator in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: colorama in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: stack_data in c:\users\kunal\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: pywin32>=300 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (311)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.5.0)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.23.1-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.1 kB ? eta -:--:--
#      ---------------------------------------- 61.1/61.1 kB ? eta 0:00:00
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 0.0/82.6 kB ? eta -:--:--
#      ---------------------------------------- 82.6/82.6 kB 4.5 MB/s eta 0:00:00
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting pywinpty>=2.0.1
#   Downloading pywinpty-3.0.2-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#      ---- ----------------------------------- 0.2/2.1 MB 7.6 MB/s eta 0:00:01
#      ------------ --------------------------- 0.6/2.1 MB 7.9 MB/s eta 0:00:01
#      -------------------- ------------------- 1.0/2.1 MB 8.3 MB/s eta 0:00:01
#      ------------------------- -------------- 1.3/2.1 MB 7.6 MB/s eta 0:00:01
#      --------------------------------- ------ 1.7/2.1 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.1 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 7.3 MB/s eta 0:00:00
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.25.1-py3-none-any.whl (90 kB)
#      ---------------------------------------- 0.0/90.0 kB ? eta -:--:--
#      ---------------------------------------- 90.0/90.0 kB 5.3 MB/s eta 0:00:00
# Collecting json5>=0.9.0
#   Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Collecting requests>=2.31
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#      ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# Collecting babel>=2.10
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#      - -------------------------------------- 0.4/10.2 MB 7.8 MB/s eta 0:00:02
#      -- ------------------------------------- 0.7/10.2 MB 7.5 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.1/10.2 MB 7.6 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.4/10.2 MB 7.6 MB/s eta 0:00:02
#      ------- -------------------------------- 1.9/10.2 MB 7.9 MB/s eta 0:00:02
#      -------- ------------------------------- 2.1/10.2 MB 7.5 MB/s eta 0:00:02
#      --------- ------------------------------ 2.5/10.2 MB 7.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 2.9/10.2 MB 7.7 MB/s eta 0:00:01
#      ------------ --------------------------- 3.3/10.2 MB 7.8 MB/s eta 0:00:01
#      -------------- ------------------------- 3.7/10.2 MB 7.8 MB/s eta 0:00:01
#      --------------- ------------------------ 4.0/10.2 MB 7.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 4.3/10.2 MB 7.6 MB/s eta 0:00:01
#      ------------------ --------------------- 4.6/10.2 MB 7.6 MB/s eta 0:00:01
#      ------------------- -------------------- 5.0/10.2 MB 7.6 MB/s eta 0:00:01
#      --------------------- ------------------ 5.4/10.2 MB 7.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 5.8/10.2 MB 7.7 MB/s eta 0:00:01
#      ------------------------ --------------- 6.2/10.2 MB 7.7 MB/s eta 0:00:01
#      ------------------------- -------------- 6.5/10.2 MB 7.7 MB/s eta 0:00:01
#      --------------------------- ------------ 6.9/10.2 MB 7.7 MB/s eta 0:00:01
#      ---------------------------- ----------- 7.3/10.2 MB 7.8 MB/s eta 0:00:01
#      ------------------------------ --------- 7.7/10.2 MB 7.8 MB/s eta 0:00:01
#      ------------------------------- -------- 8.1/10.2 MB 7.8 MB/s eta 0:00:01
#      --------------------------------- ------ 8.5/10.2 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 8.9/10.2 MB 7.9 MB/s eta 0:00:01
#      ------------------------------------ --- 9.2/10.2 MB 7.8 MB/s eta 0:00:01
#      ------------------------------------- -- 9.5/10.2 MB 7.8 MB/s eta 0:00:01
#      -------------------------------------- - 9.7/10.2 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------------  10.1/10.2 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------------- 10.2/10.2 MB 7.6 MB/s eta 0:00:00
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in c:\users\kunal\appdata\roaming\python\python310\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.14)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl (31 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ---------------------------------------- 0.0/67.6 kB ? eta -:--:--
#      ---------------------------------------- 67.6/67.6 kB 3.8 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.27.1-cp310-cp310-win_amd64.whl (228 kB)
#      ---------------------------------------- 0.0/228.4 kB ? eta -:--:--
#      ------------------------------------- 228.4/228.4 kB 14.5 MB/s eta 0:00:00
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-4.0.0-py3-none-any.whl (15 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting pyyaml>=5.3
#   Downloading pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
#      ---------------------------------------- 0.0/158.6 kB ? eta -:--:--
#      -------------------------------------- 158.6/158.6 kB 9.3 MB/s eta 0:00:00
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
#      ---------------------------------------- 0.0/107.2 kB ? eta -:--:--
#      -------------------------------------- 107.2/107.2 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: executing>=1.2.0 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\kunal\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kunal\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting rfc3987-syntax>=1.1.0
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-2.0.0-cp310-cp310-win_amd64.whl (182 kB)
#      ---------------------------------------- 0.0/182.8 kB ? eta -:--:--
#      ------------------------------------- 182.8/182.8 kB 11.5 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.23-py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.1 kB ? eta -:--:--
#      -------------------------------------- 118.1/118.1 kB 6.7 MB/s eta 0:00:00
# Collecting lark>=1.2.2
#   Downloading lark-1.3.0-py3-none-any.whl (113 kB)
#      ---------------------------------------- 0.0/113.0 kB ? eta -:--:--
#      -------------------------------------- 113.0/113.0 kB 6.4 MB/s eta 0:00:00
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#      ---------------------------------------- 66.4/66.4 kB 3.7 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20251008-py3-none-any.whl (17 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, types-python-dateutil, tomli, tinycss2, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pyparsing, pycparser, prometheus-client, pillow, pandocfilters, overrides, numpy, mistune, markupsafe, lark, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, jsonpointer, json5, idna, h11, fqdn, fonttools, defusedxml, cycler, charset_normalizer, certifi, bleach, babel, attrs, async-lru, terminado, rfc3987-syntax, requests, referencing, pandas, jinja2, httpcore, contourpy, cffi, beautifulsoup4, arrow, anyio, matplotlib, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, httpx, argon2-cffi-bindings, seaborn, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed anyio-4.11.0 argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.3.0 async-lru-2.0.5 attrs-25.4.0 babel-2.17.0 beautifulsoup4-4.14.2 bleach-6.2.0 certifi-2025.10.5 cffi-2.0.0 charset_normalizer-3.4.4 contourpy-1.3.2 cycler-0.12.1 defusedxml-0.7.1 fastjsonschema-2.21.2 fonttools-4.60.1 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 ipywidgets-8.1.7 isoduration-20.11.0 jinja2-3.1.6 json5-0.12.1 jsonpointer-3.0.0 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.3.0 jupyter-server-2.17.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.9 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab_widgets-3.0.15 kiwisolver-1.4.9 lark-1.3.0 markupsafe-3.0.3 matplotlib-3.10.7 mistune-3.1.4 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.7 notebook-shim-0.2.4 numpy-2.2.6 overrides-7.7.0 pandas-2.3.3 pandocfilters-1.5.1 pillow-11.3.0 prometheus-client-0.23.1 pycparser-2.23 pyparsing-3.2.5 python-json-logger-4.0.0 pytz-2025.2 pywinpty-3.0.2 pyyaml-6.0.3 referencing-0.37.0 requests-2.32.5 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 rpds-py-0.27.1 seaborn-0.13.2 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.8 terminado-0.18.1 tinycss2-1.4.0 tomli-2.3.0 types-python-dateutil-2.9.0.20251008 tzdata-2025.2 uri-template-1.3.0 urllib3-2.5.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.9.0 widgetsnbextension-4.0.14
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %% [markdown]
# # Aletheia Proto-Avoidance – Visualization
# Visualizing internal tension (A), stimulus kind (S1 vs S2), and agency decisions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
# --- Load history (.npz) ---
run_path = Path("../../results/run1.npz")
# run_path = Path("../../results/run_v02.npz")  # swap v01/v02 to compare

data = np.load(run_path)
A = data["A"]
acts = data["act"]
kinds = data["kind"]
steps = np.arange(len(A))

df = pd.DataFrame({
    "step": steps,
    "A": A,
    "kind": [k.decode() if isinstance(k, bytes) else k for k in kinds],
    "act": [a.decode() if isinstance(a, bytes) else a for a in acts],
})

# %%
# --- Rolling average to reveal drift ---
df["A_roll"] = df["A"].rolling(window=100, min_periods=1).mean()

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(14,6))

# Tension line
sns.lineplot(x="step", y="A_roll", data=df, color="white", linewidth=1.8)
plt.fill_between(df["step"], df["A_roll"], color="deepskyblue", alpha=0.2)

# Overlay stimulus color bands
for kind, color in {"S1":"#ff6666", "S2":"#66ff99"}.items():
    mask = df["kind"] == kind
    plt.scatter(df.loc[mask,"step"], df.loc[mask,"A"], s=4, color=color, alpha=0.4, label=kind)

# Mark pauses/refusals
for act, marker, col in [("PAUSE","o","#ffaa00"), ("REFUSE","x","#ff0000")]:
    mask = df["act"] == act
    plt.scatter(df.loc[mask,"step"], df.loc[mask,"A"], marker=marker, color=col, s=20, label=act)

plt.legend(loc="upper right")
plt.title("Aletheia – Proto-Avoidance Dynamics")
plt.xlabel("Time step")
plt.ylabel("Tension A (rolling mean)")
plt.tight_layout()
plt.show()

# %% [markdown]
# *Hesitation is the beginning of self.*

# %%
# %% [markdown]
# # Aletheia Proto-Avoidance – Visualization
# Visualizing internal tension (A), stimulus kind (S1 vs S2), and agency decisions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
# --- Load history (.npz) ---
# run_path = Path("../../results/run1.npz")
run_path = Path("../../results/run_v02b.npz")  # swap v01/v02 to compare

data = np.load(run_path)
A = data["A"]
acts = data["act"]
kinds = data["kind"]
steps = np.arange(len(A))

df = pd.DataFrame({
    "step": steps,
    "A": A,
    "kind": [k.decode() if isinstance(k, bytes) else k for k in kinds],
    "act": [a.decode() if isinstance(a, bytes) else a for a in acts],
})

# %%
# --- Rolling average to reveal drift ---
df["A_roll"] = df["A"].rolling(window=100, min_periods=1).mean()

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(14,6))

# Tension line
sns.lineplot(x="step", y="A_roll", data=df, color="white", linewidth=1.8)
plt.fill_between(df["step"], df["A_roll"], color="deepskyblue", alpha=0.2)

# Overlay stimulus color bands
for kind, color in {"S1":"#ff6666", "S2":"#66ff99"}.items():
    mask = df["kind"] == kind
    plt.scatter(df.loc[mask,"step"], df.loc[mask,"A"], s=4, color=color, alpha=0.4, label=kind)

# Mark pauses/refusals
for act, marker, col in [("PAUSE","o","#ffaa00"), ("REFUSE","x","#ff0000")]:
    mask = df["act"] == act
    plt.scatter(df.loc[mask,"step"], df.loc[mask,"A"], marker=marker, color=col, s=20, label=act)

plt.legend(loc="upper right")
plt.title("Aletheia – Proto-Avoidance Dynamics")
plt.xlabel("Time step")
plt.ylabel("Tension A (rolling mean)")
plt.tight_layout()

# %% [markdown]
# *Hesitation is the beginning of self.*
